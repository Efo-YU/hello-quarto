# %% [markdown]
# # Quarto Layout Features
#
# Tech Team
# 2024-06-15
#
# [![Open In
# Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/efo-yu/hello-quarto/blob/main/posts/2025-12-quarto-tips/index.ipynb)
#
# ## カラムレイアウト
#
# Quartoでは複雑なレイアウトも簡単に記述できます。
#
# <table>
# <colgroup>
# <col style="width: 50%" />
# <col style="width: 50%" />
# </colgroup>
# <tbody>
# <tr>
# <td style="text-align: left;"><div width="50.0%"
# data-layout-align="left">
# <h3 id="list-one">List One</h3>
# <ul>
# <li>Item A</li>
# <li>Item B</li>
# </ul>
# </div></td>
# <td style="text-align: left;"><div width="50.0%"
# data-layout-align="left">
# <h3 id="list-two">List Two</h3>
# <ul>
# <li>Item X</li>
# <li>Item Y</li>
# </ul>
# </div></td>
# </tr>
# </tbody>
# </table>
#
# 詳細は [Article Layout](../../docs/authoring/article-layout.qmd)
# を参照してください。
